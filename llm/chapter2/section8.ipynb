# %%
from huggingface_hub import InferenceClient

# Initialize client pointing to TGI endpoint
# client = InferenceClient(
#     model="http://localhost:8080",  # URL to the TGI server
# )

# Initialize client pointing to llama.cpp server
client = InferenceClient(
    model="http://0.0.0.0:8000",  # URL to the llama.cpp server
    token="sk-no-key-required",  # llama.cpp server requires this placeholder
)

# Text generation
response = client.text_generation(
    "Tell me a story",
    max_new_tokens=100,
    temperature=0.7,
    top_p=0.95,
    details=True,
    stop_sequences=[],
)
print(response.generated_text)

# For chat format
response = client.chat_completion(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Tell me a story"},
    ],
    max_tokens=100,
    temperature=0.7,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/hf-learn-nbs/.hf_venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:407, in hf_raise_for_status(response, endpoint_name)
#     406 try:
# --> 407     response.raise_for_status()
#     408 except HTTPError as e:
#
# File ~/hf-learn-nbs/.hf_venv/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: http://0.0.0.0:8000/
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[2], line 15
#       9 client = InferenceClient(
#      10     model="http://0.0.0.0:8000",  # URL to the llama.cpp server
#      11     token="sk-no-key-required",  # llama.cpp server requires this placeholder
#      12 )
#      14 # Text generation
# ---> 15 response = client.text_generation(
#      16     "Tell me a story",
#      17     max_new_tokens=100,
#      18     temperature=0.7,
#      19     top_p=0.95,
#      20     details=True,
#      21     stop_sequences=[],
#      22 )
#      23 print(response.generated_text)
#      25 # For chat format
#
# File ~/hf-learn-nbs/.hf_venv/lib/python3.12/site-packages/huggingface_hub/inference/_client.py:2413, in InferenceClient.text_generation(self, prompt, details, stream, model, adapter_id, best_of, decoder_input_details, do_sample, frequency_penalty, grammar, max_new_tokens, repetition_penalty, return_full_text, seed, stop, stop_sequences, temperature, top_k, top_n_tokens, top_p, truncate, typical_p, watermark)
#    2388         _set_unsupported_text_generation_kwargs(model, unused_params)
#    2389         return self.text_generation(  # type: ignore
#    2390             prompt=prompt,
#    2391             details=details,
#    (...)   2411             watermark=watermark,
#    2412         )
# -> 2413     raise_text_generation_error(e)
#    2415 # Parse output
#    2416 if stream:
#
# File ~/hf-learn-nbs/.hf_venv/lib/python3.12/site-packages/huggingface_hub/inference/_common.py:447, in raise_text_generation_error(http_error)
#     444     raise exception from http_error
#     446 # Otherwise, fallback to default error
# --> 447 raise http_error
#
# File ~/hf-learn-nbs/.hf_venv/lib/python3.12/site-packages/huggingface_hub/inference/_client.py:2383, in InferenceClient.text_generation(self, prompt, details, stream, model, adapter_id, best_of, decoder_input_details, do_sample, frequency_penalty, grammar, max_new_tokens, repetition_penalty, return_full_text, seed, stop, stop_sequences, temperature, top_k, top_n_tokens, top_p, truncate, typical_p, watermark)
#    2381 # Handle errors separately for more precise error messages
#    2382 try:
# -> 2383     bytes_output = self._inner_post(request_parameters, stream=stream or False)
#    2384 except HTTPError as e:
#    2385     match = MODEL_KWARGS_NOT_USED_REGEX.search(str(e))
#
# File ~/hf-learn-nbs/.hf_venv/lib/python3.12/site-packages/huggingface_hub/inference/_client.py:275, in InferenceClient._inner_post(self, request_parameters, stream)
#     272     raise InferenceTimeoutError(f"Inference call timed out: {request_parameters.url}") from error  # type: ignore
#     274 try:
# --> 275     hf_raise_for_status(response)
#     276     return response.iter_lines() if stream else response.content
#     277 except HTTPError as error:
#
# File ~/hf-learn-nbs/.hf_venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:480, in hf_raise_for_status(response, endpoint_name)
#     476     raise _format(HfHubHTTPError, message, response) from e
#     478 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     479 # as well (request id and/or server error message)
# --> 480 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: 404 Client Error: Not Found for url: http://0.0.0.0:8000/
#
# {'code': 404, 'message': 'File Not Found', 'type': 'not_found_error'}
